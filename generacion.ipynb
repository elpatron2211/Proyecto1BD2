# %%
import random
import pandas as pd

# %%
#Empresas

"""
Props:

Tipo: Fabricante, Proveedor
Nombre: Nombre de la empresa
Pais: Pais de la empresa
Telefono: Telefono de la empresa
Email: Email de la empresa

"""



def generar_empresas(cantidad):
    empresas = [["Tipo", "Nombre", "Pais", "Telefono", "Email"]]
    tipos = ['Fabricante', 'Proveedor']
    paises = ['Estados Unidos', 'Mexico', 'Canada', 'Japon', 'China', 'Alemania', 'Francia', 'Italia', 'Brasil', 'India']
    emails = ['.com', '.net']
    for i in range(cantidad):

        empresas.append(
            [random.choice(tipos),
            f'Empresa {i}',
            random.choice(paises),
            f'{random.randint(1000000000, 9999999999)}',
            f'compras@empresa{i}{random.choice(emails)}']
            )
        
    return empresas

#Productos
"""
Props:

Nombre: Nombre del producto
Precio: Precio del producto
Codigo: Codigo del producto
Tipo: Tipo de producto
Marca: Marca del producto

"""

def generar_producto(cantidad):
    productos = [["Nombre", "Precio", "Codigo", "Tipo", "Marca"]]
    
    marcas = ['Apple', 'Samsung', 'LG', 'Sony', 'Microsoft', 'HP', 'Dell', 'Asus', 'Acer', 'Lenovo']
    tipos = ['Computadora', 'Tablet', 'Smartphone', 'Smartwatch', 'Consola', 'Audifonos', 'Television', 'Impresora', 'Proyector', 'Camara']

    for i in range(cantidad):
        productos.append([
            f'Producto {i}',
            f'{random.randint(100, 9999)}',
            f'{random.randint(1000000000, 9999999999)}',
            random.choice(tipos),
            random.choice(marcas)]
        )

    return productos

#Documentos:

"""
Props:
TipoDocumento: Tipo de documento
FechaEmisión: Fecha del documento
Numero: Numero del documento
Estado: Estado del documento
Total: Total del documento

"""



def generar_documentos(cantidad):
    tipos_documentos = ['Orden de Compra', 'Despacho a Tienda', 'Transferencia a Almacen']
    estados = ['Pendiente', 'Completado']
    fechas = pd.date_range(start='1/1/2020', end='1/1/2024', freq='D')
    documentos = [["TipoDocumento", "FechaEmisión", "Numero", "Estado", "Total"]]

    for i in range(cantidad):
        documentos.append([
            random.choice(tipos_documentos),
            random.choice(fechas),
            i,
            random.choice(estados),
            f'{random.randint(100, 9999)}']
        )

    return documentos

#Almacenes

"""
Props:

Nombre: Nombre del almacen
Direccion: Direccion del almacen
Telefono: Telefono del almacen
Ciudad: Ciudad del almacen
TipoAlmacen: Tipo de almacen

"""



def generar_almacenes(cantidad):
    tipos_almacenes = ['Almacen Recepción', 'Almacen Despacho']
    ciudades = ['CDMX', 'Guadalajara', 'Monterrey', 'Tijuana', 'Puebla', 'Merida', 'Cancun', 'Acapulco', 'Veracruz', 'Toluca']
    almacenes = [["Nombre", "Direccion", "Telefono", "Ciudad", "TipoAlmacen"]]
    for i in range(cantidad):
        almacenes.append(
            [f'Almacen {i}',
            f'Calle {random.randint(1, 100)}',
            f'{random.randint(1000000000, 9999999999)}',
            random.choice(ciudades),
            random.choice(tipos_almacenes)]
        )

    return almacenes

#Tiendas

"""
Props:

Nombre: Nombre de la tienda
Direccion: Direccion de la tienda
Telefono: Telefono de la tienda
Ciudad: Ciudad de la tienda
Asesor: Gerente de la tienda

"""


def generar_tiendas(cantidad):
    gerentes = ['Juan', 'Pedro', 'Maria', 'Jose', 'Ana', 'Luis', 'Carlos', 'Fernando', 'Ricardo', 'Roberto']
    ciudades = ['CDMX', 'Guadalajara', 'Monterrey', 'Tijuana', 'Puebla', 'Merida', 'Cancun', 'Acapulco', 'Veracruz', 'Toluca']
    tiendas = [["Nombre", "Direccion", "Telefono", "Ciudad", "Asesor"]]
    for i in range(cantidad):
        tiendas.append(
            [f'Tienda {i}',
            f'Calle {random.randint(1, 100)}',
            f'{random.randint(1000000000, 9999999999)}',
            random.choice(ciudades),
            random.choice(gerentes)]
        )

    return tiendas

#Camiones

"""
Props:

Placas: Placas del camion
Marca: Marca del camion
Modelo: Modelo del camion
Capacidad: Capacidad del camion
Piloto: Piloto del camion

""" 


def generar_camiones(cantidad):
    marcas_camiones = ['Kenworth', 'Volvo', 'Freightliner', 'International', 'Peterbilt', 'Mack', 'Western Star', 'Hino', 'Isuzu', 'Ford']
    camiones = [["Placas", "Marca", "Modelo", "Capacidad", "Tipo"]]
    pilotos = ['Juan', 'Pedro', 'Maria', 'Jose', 'Ana', 'Luis', 'Carlos', 'Fernando', 'Ricardo', 'Roberto']
    placas = random.sample(range(100000, 999999), cantidad)
    for i in range(cantidad):
        camiones.append(
            [placas[i],
            random.choice(marcas_camiones),
            f'{random.randint(2000, 2022)}',
            f'{random.randint(1000, 9999)}',
            random.choice(pilotos)]
        )

    return camiones

# %%
def DISTRIBUYE_A(empresas):
    fabricantes = []
    proveedores = []
    for empresa in empresas:
        if empresa[0] == 'Fabricante':
            fabricantes.append(empresa)
        else:
            proveedores.append(empresa)

    print(fabricantes)
    print(proveedores)
    
    distribuyeA = [['fabricante', 'proveedor']]
    for i in fabricantes:
        numero_proveedores = random.randint(1, 5)
        for j in range(numero_proveedores):
            distribuyeA.append([i[1], random.choice(proveedores)[1]])



    return distribuyeA

def DISTRIBUIDO_POR(empresas, productos):
    distribuidos = [['empresa', 'producto', 'costo']]
    proveedores = []
    for empresa in empresas:
        if empresa[0] == 'Proveedor':
            proveedores.append(empresa)
    for i in productos:
        distribuidos.append([random.choice(proveedores)[1], i[0], random.randint(1, 50)])
    return distribuidos

def FABRICADO_POR(empresas, productos):
    fabricados = [['empresa', 'producto']]
    fabricantes = []
    for empresa in empresas:
        if empresa[0] == 'Fabricante':
            fabricantes.append(empresa)
    for i in productos:
        fabricados.append([random.choice(fabricantes)[1], i[0]])
    return fabricados

def INVENTARIO(almacenes, tiendas, productos):
    inventario = [['almacen', 'producto', 'cantidad']]
    for i in almacenes:
        for j in productos:
            inventario.append([i[0], j[0], random.randint(0, 100)])

    for i in tiendas:
        for j in productos:
            inventario.append([i[0], j[0], random.randint(0, 10)])
    return inventario

def DESPACHOSyENTREGAS(camiones, documentos, almacenes, tiendas):
    almacenesDes = [i for i in almacenes if i[4] == 'Almacen Despacho']
    despacho_a =  [['almacen', 'camion', 'documento']]
    completado_por = [['documento', 'camion']]
    entregado_en = ['camion', 'tienda', 'documento']
    solicitud = ['documento', 'tienda']
    for i in documentos:
        if documentos[0] == 'Despacho a Tienda':
            despacho_a.append([random.choice(almacenesDes)[0], random.choice(camiones)[0], i[2]])
            completado_por.append([i[2]], random.choice(camiones)[0])
            entregado_en.append([random.choice(camiones)[0], random.choice(tiendas)[0], i[2]])
            solicitud.append([i[2], random.choice(tiendas)[0]])
    return despacho_a, completado_por, entregado_en, solicitud

def ORDENES_DE_COMPRA_y_TRASFERENCIA(documentos, empresas, almacenes):
    empresaProv = [x for x in empresas if x[0] == 'Proveedor']
    ordenes = [['documento', 'almacen']]
    ordenado_a = [['documento', 'empresa']]
    for i in documentos:
        if i[0] == 'Orden de Compra':
            ordenes.append([i[2], random.choice(almacenes)])
            ordenado_a.append([i[2], random.choice(empresaProv)])
        elif i[0] == 'Transferencia a Almacen':
            almacen1 = random.choice(almacenes)
            almacen2 = random.choice(almacenes)
            while almacen1 == almacen2:
                almacen2 = random.choice(almacenes)
            ordenes.append([i[2], almacen1])
            ordenado_a.append([i[2], almacen2])
    return ordenes, ordenado_a

def PRODUCTOS_ORDEN(documentos, productos):
    productosOrden = [['documento', 'producto', 'cantidad']]
    for i in documentos:
        numero_prods = random.randint(1, 10)
        for j in range(numero_prods):
            productosOrden.append([i[2], random.choice(productos)[0], random.randint(1, 10)])
    return productosOrden

def DISTANCIAS(almacenes, tiendas):
    distancias = [['almacen', 'tienda', 'distancia', 'tiempo_mins', 'costo']]
    almacenesDes = [i for i in almacenes if i[4] == 'Almacen Despacho']
    for i in almacenesDes:
        for j in tiendas:
            distancias.append([i[0], j[0], random.randint(1, 100), random.randint(1, 100), random.randint(5, 500)])

    return distancias



def extract_csv(almacenes, camiones, documentos, empresas, productos, tiendas):
    pd.DataFrame(DISTRIBUYE_A(empresas)).to_csv('distribuyeA.csv', index=False)
    pd.DataFrame(DISTRIBUIDO_POR(empresas, productos)).to_csv('distribuidoPor.csv', index=False)
    pd.DataFrame(FABRICADO_POR(empresas, productos)).to_csv('fabricadoPor.csv', index=False)
    pd.DataFrame(INVENTARIO(almacenes, tiendas, productos)).to_csv('inventario.csv', index=False)
    pd.DataFrame(DESPACHOSyENTREGAS(camiones, documentos, almacenes, tiendas)).to_csv('despachosEntregas.csv', index=False)
    pd.DataFrame(ORDENES_DE_COMPRA_y_TRASFERENCIA(documentos, empresas, almacenes)).to_csv('ordenesCompraTransferencia.csv', index=False)
    pd.DataFrame(PRODUCTOS_ORDEN(documentos, productos)).to_csv('productosOrden.csv', index=False)
    pd.DataFrame(DISTANCIAS(almacenes, tiendas)).to_csv('distancias.csv', index=False)

# %%
def main(num_almacenes, num_camiones, num_documentos, num_empresas, num_productos, num_tiendas):
    almacenes = generar_almacenes(num_almacenes)
    camiones = generar_camiones(num_camiones)
    documentos = generar_documentos(num_documentos)
    empresas = generar_empresas(num_empresas)
    productos = generar_producto(num_productos)
    tiendas = generar_tiendas(num_tiendas)

    pd.DataFrame(almacenes).to_csv('almacenes.csv', index=False)
    pd.DataFrame(camiones).to_csv('camiones.csv', index=False)
    pd.DataFrame(documentos).to_csv('documentos.csv', index=False)
    pd.DataFrame(empresas).to_csv('empresas.csv', index=False)
    pd.DataFrame(productos).to_csv('productos.csv', index=False)
    pd.DataFrame(tiendas).to_csv('tiendas.csv', index=False)

    extract_csv(almacenes[1:], camiones[1:], documentos[1:], empresas[1:], productos[1:], tiendas[1:])

main(50, 100, 4000, 200, 2500, 500)
# Out:
# [['Fabricante', 'Empresa 5', 'Estados Unidos', '3969231886', 'compras@empresa5.com'], ['Fabricante', 'Empresa 8', 'Estados Unidos', '2944480960', 'compras@empresa8.net'], ['Fabricante', 'Empresa 11', 'India', '6089829286', 'compras@empresa11.net'], ['Fabricante', 'Empresa 12', 'Italia', '3329821114', 'compras@empresa12.com'], ['Fabricante', 'Empresa 13', 'Alemania', '8897164006', 'compras@empresa13.com'], ['Fabricante', 'Empresa 16', 'Mexico', '7763526120', 'compras@empresa16.net'], ['Fabricante', 'Empresa 17', 'Alemania', '5038491795', 'compras@empresa17.com'], ['Fabricante', 'Empresa 19', 'Francia', '3071475219', 'compras@empresa19.net'], ['Fabricante', 'Empresa 20', 'Alemania', '9439894324', 'compras@empresa20.com'], ['Fabricante', 'Empresa 21', 'Francia', '3768524464', 'compras@empresa21.net'], ['Fabricante', 'Empresa 22', 'Brasil', '7226225795', 'compras@empresa22.com'], ['Fabricante', 'Empresa 25', 'India', '8460213746', 'compras@empresa25.com'], ['Fabricante', 'Empresa 27', 'Francia', '4028060099', 'compras@empresa27.net'], ['Fabricante', 'Empresa 32', 'China', '8323979232', 'compras@empresa32.com'], ['Fabricante', 'Empresa 36', 'Italia', '3932056634', 'compras@empresa36.com'], ['Fabricante', 'Empresa 38', 'Mexico', '7535992391', 'compras@empresa38.net'], ['Fabricante', 'Empresa 40', 'China', '4724292472', 'compras@empresa40.com'], ['Fabricante', 'Empresa 43', 'Mexico', '4382755249', 'compras@empresa43.net'], ['Fabricante', 'Empresa 44', 'Francia', '7850137683', 'compras@empresa44.net'], ['Fabricante', 'Empresa 46', 'Alemania', '8517578980', 'compras@empresa46.net'], ['Fabricante', 'Empresa 48', 'Japon', '7461157999', 'compras@empresa48.net'], ['Fabricante', 'Empresa 51', 'India', '5695262236', 'compras@empresa51.net'], ['Fabricante', 'Empresa 53', 'Francia', '5882134662', 'compras@empresa53.net'], ['Fabricante', 'Empresa 55', 'Japon', '8914272123', 'compras@empresa55.net'], ['Fabricante', 'Empresa 56', 'Mexico', '9622379928', 'compras@empresa56.net'], ['Fabricante', 'Empresa 59', 'Francia', '6270242929', 'compras@empresa59.net'], ['Fabricante', 'Empresa 61', 'Mexico', '3122876181', 'compras@empresa61.com'], ['Fabricante', 'Empresa 64', 'China', '9887201962', 'compras@empresa64.net'], ['Fabricante', 'Empresa 65', 'Alemania', '2009784902', 'compras@empresa65.net'], ['Fabricante', 'Empresa 69', 'China', '8191217841', 'compras@empresa69.net'], ['Fabricante', 'Empresa 71', 'Mexico', '5951909224', 'compras@empresa71.com'], ['Fabricante', 'Empresa 74', 'Brasil', '8349259023', 'compras@empresa74.net'], ['Fabricante', 'Empresa 76', 'Brasil', '7892764326', 'compras@empresa76.com'], ['Fabricante', 'Empresa 79', 'Francia', '5920244523', 'compras@empresa79.com'], ['Fabricante', 'Empresa 81', 'Canada', '9966557267', 'compras@empresa81.com'], ['Fabricante', 'Empresa 84', 'Canada', '4366905239', 'compras@empresa84.net'], ['Fabricante', 'Empresa 88', 'Francia', '9443296902', 'compras@empresa88.net'], ['Fabricante', 'Empresa 89', 'Alemania', '4273811346', 'compras@empresa89.net'], ['Fabricante', 'Empresa 91', 'Mexico', '5237892809', 'compras@empresa91.net'], ['Fabricante', 'Empresa 95', 'India', '7491558827', 'compras@empresa95.net'], ['Fabricante', 'Empresa 96', 'India', '6514129953', 'compras@empresa96.com'], ['Fabricante', 'Empresa 97', 'Canada', '9883515684', 'compras@empresa97.net'], ['Fabricante', 'Empresa 103', 'India', '1118875605', 'compras@empresa103.com'], ['Fabricante', 'Empresa 105', 'Brasil', '2574509813', 'compras@empresa105.net'], ['Fabricante', 'Empresa 107', 'Mexico', '2199077687', 'compras@empresa107.net'], ['Fabricante', 'Empresa 108', 'Canada', '5479753517', 'compras@empresa108.net'], ['Fabricante', 'Empresa 110', 'Alemania', '7611377403', 'compras@empresa110.net'], ['Fabricante', 'Empresa 111', 'Estados Unidos', '6614083399', 'compras@empresa111.com'], ['Fabricante', 'Empresa 112', 'Estados Unidos', '9198913929', 'compras@empresa112.com'], ['Fabricante', 'Empresa 116', 'China', '9207766793', 'compras@empresa116.com ...
# [['Proveedor', 'Empresa 0', 'Canada', '2494574220', 'compras@empresa0.net'], ['Proveedor', 'Empresa 1', 'China', '8404337838', 'compras@empresa1.com'], ['Proveedor', 'Empresa 2', 'Alemania', '2317026896', 'compras@empresa2.net'], ['Proveedor', 'Empresa 3', 'India', '3536061985', 'compras@empresa3.com'], ['Proveedor', 'Empresa 4', 'China', '4198097110', 'compras@empresa4.net'], ['Proveedor', 'Empresa 6', 'Brasil', '3232000255', 'compras@empresa6.net'], ['Proveedor', 'Empresa 7', 'Alemania', '9884860646', 'compras@empresa7.net'], ['Proveedor', 'Empresa 9', 'India', '2300832072', 'compras@empresa9.com'], ['Proveedor', 'Empresa 10', 'Francia', '1564580734', 'compras@empresa10.com'], ['Proveedor', 'Empresa 14', 'Brasil', '8760411369', 'compras@empresa14.net'], ['Proveedor', 'Empresa 15', 'Canada', '8829174524', 'compras@empresa15.net'], ['Proveedor', 'Empresa 18', 'India', '4633609598', 'compras@empresa18.com'], ['Proveedor', 'Empresa 23', 'Francia', '9722219855', 'compras@empresa23.net'], ['Proveedor', 'Empresa 24', 'Estados Unidos', '5493001142', 'compras@empresa24.net'], ['Proveedor', 'Empresa 26', 'China', '3084408774', 'compras@empresa26.net'], ['Proveedor', 'Empresa 28', 'Alemania', '8769044123', 'compras@empresa28.com'], ['Proveedor', 'Empresa 29', 'China', '9123390991', 'compras@empresa29.net'], ['Proveedor', 'Empresa 30', 'Alemania', '4100480726', 'compras@empresa30.com'], ['Proveedor', 'Empresa 31', 'Mexico', '4743297425', 'compras@empresa31.com'], ['Proveedor', 'Empresa 33', 'Brasil', '9019652565', 'compras@empresa33.com'], ['Proveedor', 'Empresa 34', 'Mexico', '9991168107', 'compras@empresa34.net'], ['Proveedor', 'Empresa 35', 'Brasil', '2759187965', 'compras@empresa35.com'], ['Proveedor', 'Empresa 37', 'Brasil', '2013159564', 'compras@empresa37.net'], ['Proveedor', 'Empresa 39', 'Alemania', '1365217383', 'compras@empresa39.net'], ['Proveedor', 'Empresa 41', 'India', '3564572578', 'compras@empresa41.com'], ['Proveedor', 'Empresa 42', 'Francia', '3667597594', 'compras@empresa42.com'], ['Proveedor', 'Empresa 45', 'Estados Unidos', '7791780068', 'compras@empresa45.com'], ['Proveedor', 'Empresa 47', 'China', '1558858681', 'compras@empresa47.net'], ['Proveedor', 'Empresa 49', 'Canada', '3314522725', 'compras@empresa49.com'], ['Proveedor', 'Empresa 50', 'Canada', '9605086445', 'compras@empresa50.com'], ['Proveedor', 'Empresa 52', 'Estados Unidos', '7060483439', 'compras@empresa52.net'], ['Proveedor', 'Empresa 54', 'Japon', '5094187800', 'compras@empresa54.com'], ['Proveedor', 'Empresa 57', 'Japon', '7721301397', 'compras@empresa57.com'], ['Proveedor', 'Empresa 58', 'Brasil', '5768947833', 'compras@empresa58.net'], ['Proveedor', 'Empresa 60', 'Brasil', '3356708298', 'compras@empresa60.com'], ['Proveedor', 'Empresa 62', 'Japon', '7858233080', 'compras@empresa62.net'], ['Proveedor', 'Empresa 63', 'Estados Unidos', '6708912952', 'compras@empresa63.net'], ['Proveedor', 'Empresa 66', 'Japon', '8269233584', 'compras@empresa66.com'], ['Proveedor', 'Empresa 67', 'Canada', '2972616914', 'compras@empresa67.com'], ['Proveedor', 'Empresa 68', 'Francia', '9961091911', 'compras@empresa68.com'], ['Proveedor', 'Empresa 70', 'Japon', '4563312256', 'compras@empresa70.com'], ['Proveedor', 'Empresa 72', 'India', '7332992883', 'compras@empresa72.net'], ['Proveedor', 'Empresa 73', 'Canada', '3283280081', 'compras@empresa73.com'], ['Proveedor', 'Empresa 75', 'Estados Unidos', '8980147087', 'compras@empresa75.net'], ['Proveedor', 'Empresa 77', 'Mexico', '5849184826', 'compras@empresa77.net'], ['Proveedor', 'Empresa 78', 'India', '5970764519', 'compras@empresa78.com'], ['Proveedor', 'Empresa 80', 'Italia', '2673016435', 'compras@empresa80.com'], ['Proveedor', 'Empresa 82', 'China', '7425660008', 'compras@empresa82.com'], ['Proveedor', 'Empresa 83', 'Mexico', '3604678633', 'compras@empresa83.com'], ['Proveedor', 'Empresa 85', 'Japon', '3554936350', 'compras@empresa85.com'], ['Proveedor', 'Empresa 86', 'China', '5023713017', 'compras@empresa86.com'], [' ...
